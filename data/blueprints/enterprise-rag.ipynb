# %% [markdown]
# # PLACEHOLDER: Replace this file with NVIDIA Enterprise RAG blueprint
#
# Download the real notebook from: https://github.com/NVIDIA-AI-Blueprints/rag (release-v2.5.0 `notebooks/launchable.ipynb`).
#
# See `data/blueprints/README.md` for setup instructions.

# %% [markdown]
# **Goal:** {{GOAL}}
#
# **Domain:** {{DOMAIN}}
#
# **Compliance:** {{COMPLIANCE_LIST}}
#
# **Target latency:** {{TARGET_LATENCY_MS}} ms (p95)
#
# **Target accuracy:** {{TARGET_ACCURACY}}

# %%
# Placeholder code cell — replace with actual blueprint setup.
# The real Enterprise RAG blueprint clones the rag repo at `release-v2.5.0`,
# runs `deploy_all()` across 4 docker-compose files (nims.yaml, vectordb.yaml,
# docker-compose-ingestor-server.yaml, docker-compose-rag-server.yaml), and
# exposes rag-server on port 8081, ingestor-server on 8082.
print('Placeholder: real blueprint content goes here')
